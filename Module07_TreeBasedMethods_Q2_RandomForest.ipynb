# %% [markdown]
# # M7Q2 : Random Forest Algorithm

# %%
# Importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
# Reading and displaying the file
file = pd.read_csv('Iris.csv')
file.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Removing the first column
file = file.iloc[:,1:]
file
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Looking at the column names
file.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# Checking for null values and datatypes
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# There are no null values and the datatypes are appropriate.

# %%
# Basic statistics of the variables
file.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# There are no values that stand out as obviously wrong.

# %%
# Creating a pairplot to look at the relations between the variables
sns.pairplot(file, hue = 'Species', corner = True)

# %% [markdown]
# ## Using the random forest algorithm

# %%
# Separating the independent and dependent variables
X = file[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
Y = file['Species']
#X
#Y

# %%
splits = [0.25,0.30,0.35,0.40] #The different test size ratios
accu = [] #An empty list that the accuracy values can be appended onto

# Creating the classifier
clf = RandomForestClassifier(n_estimators=100)

for testsize in splits:
    # Train and test splitting
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = testsize)

    # Training 
    clf.fit(X_train,y_train)

    # Creating a series with predictions
    y_pred=clf.predict(X_test)

    accu.append(metrics.accuracy_score(y_test, y_pred))
    
    print('For test size =',testsize,':','\n\n')#,classification_report(y_test, y_pred))
    
    print('The Precision, Recall, and F1 score:')
    print('________________________________________________________\n\n'
          ,classification_report(y_test, y_pred),
          '\n________________________________________________________\n\n')
    
    print('The confusion matrix: \n')

    # Heatmap showing the confusion matrix values
    classnames = ['Iris-setosa','Iris-versicolor','Iris-virginica']
    classnames_short = ['setosa','versicolor','virginica']
    sns.set(rc = {'figure.figsize':(3,2.5)})
    mx = confusion_matrix(y_test, y_pred, labels = classnames)
    sns.heatmap(mx, annot = True,xticklabels = classnames_short, yticklabels = classnames_short)
    plt.show()
    print('\n')
    
    # Calculating sensitivity 
    print('Sensitivity\n______________________________________\n')
    for i in range(len(classnames)):
        tp = mx[i][i]                                             # tp is true positive
        fn = sum(mx[i])                                           # fn is false negative
        print ('For',classnames[i],', sensitivity =',
                round(tp/fn,2))                      
    print('______________________________________\n\n')
    
    # Calculating specificity
    print('Specificity\n______________________________________\n')
    for i in range(len(classnames)):
        tn = sum(sum(mx)) - sum(mx)[i] - sum(mx[i]) + mx[i][i]    #tn is true negative
        fp = sum(mx.transpose()[i]) - mx[i][i]                    #fp is false positive
        print ('For',classnames[i],', specificity =',
                round(tn/(tn+fp),2))        
    print('______________________________________\n\n')
# Out:
# For test size = 0.25 :
#
#
# The Precision, Recall, and F1 score:
# ________________________________________________________
#
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.92      0.96        13
#
#        accuracy                           0.97        38
#       macro avg       0.98      0.97      0.97        38
#    weighted avg       0.98      0.97      0.97        38
#
# ________________________________________________________
#
#
# The confusion matrix:
# Sensitivity
# ______________________________________
#
# For Iris-setosa , sensitivity = 1.0
# For Iris-versicolor , sensitivity = 1.0
# For Iris-virginica , sensitivity = 0.92
# ______________________________________
#
#
# Specificity
# ______________________________________
#
# For Iris-setosa , specificity = 1.0
# For Iris-versicolor , specificity = 0.96
# For Iris-virginica , specificity = 1.0
# ______________________________________
#
#
# For test size = 0.3 :
#
#
# The Precision, Recall, and F1 score:
# ________________________________________________________
#
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.83      1.00      0.91        15
#  Iris-virginica       1.00      0.77      0.87        13
#
#        accuracy                           0.93        45
#       macro avg       0.94      0.92      0.93        45
#    weighted avg       0.94      0.93      0.93        45
#
# ________________________________________________________
#
#
# The confusion matrix:
# Sensitivity
# ______________________________________
#
# For Iris-setosa , sensitivity = 1.0
# For Iris-versicolor , sensitivity = 1.0
# For Iris-virginica , sensitivity = 0.77
# ______________________________________
#
#
# Specificity
# ______________________________________
#
# For Iris-setosa , specificity = 1.0
# For Iris-versicolor , specificity = 0.9
# For Iris-virginica , specificity = 1.0
# ______________________________________
#
#
# For test size = 0.35 :
#
#
# The Precision, Recall, and F1 score:
# ________________________________________________________
#
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        13
# Iris-versicolor       0.83      1.00      0.90        19
#  Iris-virginica       1.00      0.81      0.89        21
#
#        accuracy                           0.92        53
#       macro avg       0.94      0.94      0.93        53
#    weighted avg       0.94      0.92      0.92        53
#
# ________________________________________________________
#
#
# The confusion matrix:
# Sensitivity
# ______________________________________
#
# For Iris-setosa , sensitivity = 1.0
# For Iris-versicolor , sensitivity = 1.0
# For Iris-virginica , sensitivity = 0.81
# ______________________________________
#
#
# Specificity
# ______________________________________
#
# For Iris-setosa , specificity = 1.0
# For Iris-versicolor , specificity = 0.88
# For Iris-virginica , specificity = 1.0
# ______________________________________
#
#
# For test size = 0.4 :
#
#
# The Precision, Recall, and F1 score:
# ________________________________________________________
#
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        21
# Iris-versicolor       0.85      0.89      0.87        19
#  Iris-virginica       0.89      0.85      0.87        20
#
#        accuracy                           0.92        60
#       macro avg       0.91      0.91      0.91        60
#    weighted avg       0.92      0.92      0.92        60
#
# ________________________________________________________
#
#
# The confusion matrix:
# Sensitivity
# ______________________________________
#
# For Iris-setosa , sensitivity = 1.0
# For Iris-versicolor , sensitivity = 0.89
# For Iris-virginica , sensitivity = 0.85
# ______________________________________
#
#
# Specificity
# ______________________________________
#
# For Iris-setosa , specificity = 1.0
# For Iris-versicolor , specificity = 0.93
# For Iris-virginica , specificity = 0.95
# ______________________________________

# %% [markdown]
# #### Table showing accuracy for different test sizes

# %%
# Creating an empty dataframe
a = pd.DataFrame()
# Adding a column that contains the test sizes
a['Test_size'] = splits
# Adding a column that contains the corresponding accuracy values obtained
a['Accuracy'] = accu
# Displaying the dataframe
a
# Out:
#    Test_size  Accuracy
# 0       0.25  0.973684
# 1       0.30  0.933333
# 2       0.35  0.924528
# 3       0.40  0.916667

# %% [markdown]
# ### AUC ROC curves

# %% [markdown]
# #### The ROC curves can only be plotted when it is a binary classification problem.
# #### Here, to plot those curves, we use one hot encoding on the 'Species' column and plot the curves for each class separately.

# %%
file2 = pd.get_dummies(file)
file2.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2
#
#    Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                    1                        0                       0
# 1                    1                        0                       0
# 2                    1                        0                       0
# 3                    1                        0                       0
# 4                    1                        0                       0

# %%
for testsize in splits:
    print('For testsize =', testsize,'\n_____________________________________')
    
    for i in range(len(['Species_Iris-setosa','Species_Iris-versicolor','Species_Iris-virginica'])):    
        X2 = file2[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
        Y2 = file2[['Species_Iris-setosa','Species_Iris-versicolor','Species_Iris-virginica'][i]]

        # Creating the classifier
        clf = RandomForestClassifier(n_estimators=100)

        # Train and test splitting
        X2_train, X2_test, y2_train, y2_test = train_test_split(X2, Y2, test_size = testsize)

        # Training 
        clf.fit(X2_train,y2_train)

        #define metrics
        y2_pred_proba = clf.predict_proba(X2_test)[::,1]
        fpr, tpr, _ = roc_curve(y2_test,  y2_pred_proba) #fpr: false positive rate; tpr: true positive rate
        auc = round(roc_auc_score(y2_test, y2_pred_proba),3)

        #create ROC curve
        from math import *
        c1 = (2**i)-2*i
        c2 = (cos(i*pi) - 1)/-2
        c3 = (2**(abs(i-2)))-2*(abs(i-2))
        rnclr = [c1, c2, c3]
        
        sns.set(rc = {'figure.figsize':(5,5)})
        plt.plot(fpr,tpr,label="AUC="+str(auc),color = rnclr)
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.title('ROC curve for testsize = ' + str(testsize)+'\n', fontsize = '15')
        first_legend = plt.legend(('setosa', 'versicolor', 'virginica'), loc = 8)
        plt.gca().add_artist(first_legend)
        plt.legend(loc = 'lower right')
    plt.show()  
    print('\n_____________________________________')
# Out:
# For testsize = 0.25
# _____________________________________
# _____________________________________
# For testsize = 0.3
# _____________________________________
# _____________________________________
# For testsize = 0.35
# _____________________________________
# _____________________________________
# For testsize = 0.4
# _____________________________________
# _____________________________________
